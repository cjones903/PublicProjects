# %%
from gmusicapi import Mobileclient
import pandas as pd
import numpy as np
from PyLyrics import *
import string
from sklearn.cross_validation import train_test_split
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import f1_score, classification_report

# %% [markdown]
# # Recently, I've been curious about some real life applications of NLP. Here, I've decided to try my hand at using NLP to perform music genre classifiction based on lyrics. Is it true that country singers only sing about mama and trucks? Do rappers only rap about money, cars, and clothes? NLP can offer some insight into these patterns.

# %% [markdown]
# ### I start by using my personal music playlist as a collection of music to examine. I listen to a lot of everything, and it seems like a good place to start. Thankfully, GmusicAPI exists. This API allows me to access my personal playlists and extract data. For this analysis, I'm going to analyze my playlist of songs that I've 'thumbbed up'. GmusicAPI makes it simple to login and access A LOT of information about music.

# %%
api = Mobileclient()
api.login(username, password, Mobileclient.FROM_MAC_ADDRESS)
playlists = api.get_all_user_playlist_contents()

# %% [markdown]
# ### Here, I'm creating and filling a dataframe to hold some information that I will later use to retrieve lyrics. I'm intentionally ignoring some potentially informative information that GmusicAPI offers because I want to limit the analysis to lyrics. Also, some information isn't available for all songs so ignoring those songs for now.

# %%
songDataFrame = pd.DataFrame(columns=('title','genre','artist','lyrics','lyricsCleaned'))
for playlist in playlists:
    if playlist['name'] == 'ThumbbedUP':
        currentPlaylist = playlist['tracks']
        for song in currentPlaylist:
            try:
                currentSong = pd.DataFrame.from_dict({'title':[song['track']['title']], 'genre':[song['track']['genre']],'artist':[song['track']['artist']]})
                songDataFrame = songDataFrame.append(currentSong,ignore_index=True)
            except Exception as err:
                pass

# %% [markdown]
# ### Lets take a look at what we have so far.

# %%
songDataFrame
# Out:
#                                     artist               genre lyrics  \
# 0                                Sam Smith                 Pop    NaN
# 1                              Wayne Toups                Folk    NaN
# 2                         Robert Earl Keen         Alt Country    NaN
# 3                               John Mayer  Adult Contemporary    NaN
# 4                          Imagine Dragons   Alternative/Indie    NaN
# 5                              Hayes Carll                Folk    NaN
# 6                               Billy Paul            R&B/Soul    NaN
# 7                                    Kaleo   Alternative/Indie    NaN
# 8                                Tom Petty                Rock    NaN
# 9                                Tom Petty                Rock    NaN
# 10      Hannah Williams & The Affirmations            R&B/Soul    NaN
# 11                                   JAY-Z         Hip-Hop/Rap    NaN
# 12                            The Darkness           Hard Rock    NaN
# 13                               Lifehouse           '00s Rock    NaN
# 14                            Foo Fighters    '90s Alternative    NaN
# 15                               Pearl Jam    '90s Alternative    NaN
# 16                                  Weezer    '90s Alternative    NaN
# 17                                 Nirvana    '90s Alternative    NaN
# 18                             The Bravery    '00s Alternative    NaN
# 19                             The Killers           '00s Rock    NaN
# 20                    Turnpike Troubadours             Country    NaN
# 21                            BROCKHAMPTON         Hip-Hop/Rap    NaN
# 22                              Steve Aoki    Dance/Electronic    NaN
# 23                              Steve Aoki    Dance/Electronic    NaN
# 24                                 Wu-Tang         Hip-Hop/Rap    NaN
# 25                              Macklemore         Hip-Hop/Rap    NaN
# 26                           Darius Rucker             Country    NaN
# 27                               DJ Khaled         Hip-Hop/Rap    NaN
# 28                                   Drake         Hip-Hop/Rap    NaN
# 29   Drake, Kanye West, Lil Wayne & Eminem        '00s Hip-Hop    NaN
# ..                                     ...                 ...    ...
# 579                             AWOLNATION                Rock    NaN
# 580                            Hayes Carll             Country    NaN
# 581                                  Drake   Hip-Hop Hitmakers    NaN
# 582                                Birdman         Hip-Hop/Rap    NaN
# 583                                50 Cent         Hip-Hop/Rap    NaN
# 584                      Waka Flocka Flame        '10s Hip-Hop    NaN
# 585                              Rick Ross         Hip-Hop/Rap    NaN
# 586                              Shawty Lo         Hip-Hop/Rap    NaN
# 587                            Gudda Gudda         Hip-Hop/Rap    NaN
# 588                              Lil Wayne         Hip-Hop/Rap    NaN
# 589                            Gorilla Zoe         Hip-Hop/Rap    NaN
# 590                         DJ Bobby Black         Hip-Hop/Rap    NaN
# 591                                Birdman         Hip-Hop/Rap    NaN
# 592                          Juelz Santana         Hip-Hop/Rap    NaN
# 593                            Gudda Gudda         Hip-Hop/Rap    NaN
# 594                              Shawty Lo         Hip-Hop/Rap    NaN
# 595                                Birdman         Hip-Hop/Rap    NaN
# 596                      Waka Flocka Flame        '10s Hip-Hop    NaN
# 597                               Ludacris         Hip-Hop/Rap    NaN
# 598                            Wiz Khalifa         Hip-Hop/Rap    NaN
# 599                                  Rozay         Hip-Hop/Rap    NaN
# 600                             Gucci Mane         Hip-Hop/Rap    NaN
# 601                      Waka Flocka Flame        '10s Hip-Hop    NaN
# 602                                   Tyga         Hip-Hop/Rap    NaN
# 603                              Lil Wayne         Hip-Hop/Rap    NaN
# 604                                   T.I.         Hip-Hop/Rap    NaN
# 605                             Gucci Mane         Hip-Hop/Rap    NaN
# 606               Evil Empire and Dj Drama         Hip-Hop/Rap    NaN
# 607                            Gorilla Zoe         Hip-Hop/Rap    NaN
# 608                              Lil Wayne         Hip-Hop/Rap    NaN
#
#     lyricsCleaned                                              title
# 0             NaN                               Too Good At Goodbyes
# 1             NaN                     Take My Hand (feat. Zydecajun)
# 2             NaN                           The Road Goes On Forever
# 3             NaN                                   Half of My Heart
# 4             NaN                                           Believer
# 5             NaN                                      The Magic Kid
# 6             NaN                                  Me and Mrs. Jones
# 7             NaN                                     Way Down We Go
# 8             NaN                               Runnin' Down A Dream
# 9             NaN                                       Free Fallin'
# 10            NaN                           Late Nights & Heartbreak
# 11            NaN                                               4:44
# 12            NaN                   I Believe In A Thing Called Love
# 13            NaN                                Hanging By a Moment
# 14            NaN                                           Everlong
# 15            NaN                                          Even Flow
# 16            NaN                                    Say It Ain't So
# 17            NaN                                    Come As You Are
# 18            NaN                               Time Won't Let Me Go
# 19            NaN                                When You Were Young
# 20            NaN                               Sunday Morning Paper
# 21            NaN                                               STAR
# 22            NaN       I Love It When You Cry (Moxoki) (Radio Edit)
# 23            NaN                                       Just Hold On
# 24            NaN   Lesson Learn'd (feat. Inspectah Deck and Redman)
# 25            NaN                       Over It (feat. Donna Missal)
# 26            NaN                                              Don't
# 27            NaN                             For Free (feat. Drake)
# 28            NaN                                    Best I Ever Had
# 29            NaN                                 Forever (Explicit)
# ..            ...                                                ...
# 579           NaN                                         All I Need
# 580           NaN                                          KMAG YOYO
# 581           NaN                        The Motto (feat. Lil Wayne)
# 582           NaN          About All That (Explicit) (feat. Fat Joe)
# 583           NaN  I Don't Know, Officer (Explicit) (feat. Lloyd ...
# 584           NaN  F**k The Club Up (feat. Pastor Troy & Slim Dun...
# 585           NaN                                      Feel Dat Heat
# 586           NaN                                         Dunn, Dunn
# 587           NaN              I Got That Gangsta (feat. Lil’ Wayne)
# 588           NaN                                         What U Kno
# 589           NaN                                           I'm Dumb
# 590           NaN                       All Alone (feat. Lil’ Wayne)
# 591           NaN          Mo Milly (Explicit) (feat. Drake & Bun B)
# 592           NaN                                          By Myself
# 593           NaN                              The Dungeon (Screwed)
# 594           NaN       They Know [Dey Know] (Amended Album Version)
# 595           NaN           Cali Dro (Explicit) (feat. Daz & Kurupt)
# 596           NaN  O Let's Do It (Feat. Cap) [Explicit Album Vers...
# 597           NaN                                     Been Puttin On
# 598           NaN                                        Taylor Made
# 599           NaN                                          10 Bricks
# 600           NaN              All About The Money [feat. Rick Ross]
# 601           NaN  Bricksquad (feat. Gudda Gudda) [Explicit Album...
# 602           NaN      Just Wanna Hit (Feat. Short Dawg & Lil Wayne)
# 603           NaN                                         Gucci Land
# 604           NaN                                            Like So
# 605           NaN             Stupid Wild [feat. Lil Wayne, Cam'Ron]
# 606           NaN                                      S On My Chest
# 607           NaN                                      Journal Entry
# 608           NaN                                            Spitter
#
# [609 rows x 5 columns]

# %%
songDataFrame.describe()
# Out:
#              artist              genre  lyrics  lyricsCleaned     title
# count           609                609     0.0            0.0       609
# unique          355                 63     0.0            0.0       567
# top     Eric Church  Alternative/Indie     NaN            NaN  Everlong
# freq             12                 65     NaN            NaN         4

# %% [markdown]
# ### So far so good. One thing I've noticed is a large number of uniqe genres. I'm going to try to handle that by merging some of the super specific genres into some more general genres that I will analyze later. I'm sure theres a more intelligent way to do this, but I'll work on that later.

# %%
songDataFrame.loc[songDataFrame['genre'].str.contains('Rock', case=False), 'genre'] = 'Rock'
songDataFrame.loc[songDataFrame['genre'].str.contains('Hip-Hop', case=False), 'genre'] = 'Rap'
songDataFrame.loc[songDataFrame['genre'].str.contains('Country', case=False), 'genre'] = 'Country'
songDataFrame.loc[songDataFrame['genre'].str.contains('Metal', case=False), 'genre'] = 'Rock'
songDataFrame.loc[songDataFrame['genre'].str.contains('Pop', case=False), 'genre'] = 'Pop'
songDataFrame.loc[songDataFrame['genre'].str.contains('Punk', case=False), 'genre'] = 'Rock'

# %%
songDataFrame.describe()
# Out:
#              artist genre  lyrics  lyricsCleaned     title
# count           609   609     0.0            0.0       609
# unique          355    31     0.0            0.0       567
# top     Eric Church  Rock     NaN            NaN  Everlong
# freq             12   162     NaN            NaN         4

# %% [markdown]
# ### So converting some specific genres to general genres netted a pretty good reduction in number of unique genres. I'm going to further limit the analysis to rock, rap, and country music.

# %%
songDataFrame = songDataFrame[songDataFrame['genre'].isin(['Rock','Country','Rap'])]

# %%
songDataFrame.describe()
# Out:
#              artist genre  lyrics  lyricsCleaned             title
# count           301   301     0.0            0.0               301
# unique          173     3     0.0            0.0               286
# top     Eric Church  Rock     NaN            NaN  Sixteen Saltines
# freq             12   162     NaN            NaN                 2

# %% [markdown]
# ### Here, I'm going to use the PyLyrics API to retrieve the actual lyrics. This API is a life saver. It will automatically retrive lyrics for most songs from lyrics.wikia.com given some information. Here I'm going to use title and artist to retrieve the lyrics.

# %%
for row in songDataFrame.iterrows():
    try:
        lyrics = PyLyrics.getLyrics(row[1][0],row[1][4])
    except:
        lyrics = ['']
    songDataFrame.loc[row[0]]['lyrics'] = lyrics

# %% [markdown]
# ### Prepping the data for text classification. This is pretty kludgey, but I don't want punctuation or special characters to affect the analysis.

# %%
rmPunctuation = str.maketrans('', '', string.punctuation+ '(){}<>')
rmNewline = str.maketrans('\n',' ')
for row in songDataFrame.iterrows():
    songDataFrame.loc[row[0]]['lyricsCleaned'] = str(row[1][2]).translate(rmPunctuation)
    songDataFrame.loc[row[0]]['lyricsCleaned'] = str(songDataFrame.loc[row[0]]['lyricsCleaned']).translate(rmNewline)
songDataFrame = songDataFrame[songDataFrame['lyrics'].map(len) > 1]
songDataFrame
# Out:
#                        artist    genre  \
# 2            Robert Earl Keen  Country
# 8                   Tom Petty     Rock
# 9                   Tom Petty     Rock
# 11                      JAY-Z      Rap
# 12               The Darkness     Rock
# 13                  Lifehouse     Rock
# 19                The Killers     Rock
# 25                 Macklemore      Rap
# 27                  DJ Khaled      Rap
# 28                      Drake      Rap
# 30                      Drake      Rap
# 31                      Drake      Rap
# 32                      Drake      Rap
# 36               Foo Fighters     Rock
# 38                Eric Church  Country
# 39                  The Doors     Rock
# 41                  The Doors     Rock
# 48              Lionel Richie  Country
# 50              Easton Corbin  Country
# 51              Easton Corbin  Country
# 52                Eric Church  Country
# 53                     Webbie      Rap
# 54                   Juvenile      Rap
# 58               Rae Sremmurd      Rap
# 61                 Mike Jones      Rap
# 62                  Fetty Wap      Rap
# 63              Jamey Johnson  Country
# 64             Kendrick Lamar      Rap
# 76                      Foals     Rock
# 77                      Foals     Rock
# ..                        ...      ...
# 544               The Killers     Rock
# 547             Kings Of Leon     Rock
# 549                      Muse     Rock
# 550           Alice In Chains     Rock
# 551           Velvet Revolver     Rock
# 557   Queens Of The Stone Age     Rock
# 559  Rage Against The Machine     Rock
# 562               Limp Bizkit     Rock
# 563                       311     Rock
# 564                   OutKast      Rap
# 565                  Coldplay     Rock
# 567            Alabama Shakes     Rock
# 568              Foo Fighters     Rock
# 569              Ryan Bingham  Country
# 572              Brad Paisley  Country
# 576               Eric Church  Country
# 578                   DJ Kool      Rap
# 579                AWOLNATION     Rock
# 580               Hayes Carll  Country
# 581                     Drake      Rap
# 583                   50 Cent      Rap
# 586                 Shawty Lo      Rap
# 588                 Lil Wayne      Rap
# 589               Gorilla Zoe      Rap
# 591                   Birdman      Rap
# 592             Juelz Santana      Rap
# 596         Waka Flocka Flame      Rap
# 601         Waka Flocka Flame      Rap
# 604                      T.I.      Rap
# 608                 Lil Wayne      Rap
#
#                                                 lyrics  \
# 2    Sherry was a waitress at the only joint in tow...
# 8    It was a beautiful day, the sun beat down\nI h...
# 9    Unfortunately, we are not licensed to display ...
# 11   Do I find it so hard\nWhen I know in my heart\...
# 12   Can't explain all the feelings that you're mak...
# 13   Desperate for changing\nStarving for truth\nI'...
# 19   You sit there in your heartache\nWaitin' on so...
# 25   Donna Missal\nWe got that bad love, but it tas...
# 27   Would you fuck me for free?\nAnother one\nWe t...
# 28   You know alot of girls be\nThinkin' my songs a...
# 30   Started\n(Zombie on the track)\n\nStarted from...
# 31   I'm the fuckin' man, y'all don't get it, do ya...
# 32   Kyla\nBaby, I like your style!\n\nDrake\nGrips...
# 36   Look out 'cause you know what you're doing\nTu...
# 38   Turn on a neon light\nAt least make it feel li...
# 39   People are strange when you're a stranger\nFac...
# 41   You know that it would be untrue\nYou know tha...
# 48   Know it sounds funny\nBut, I just can't stand ...
# 50   So here we are, here all alone\nThe band quit ...
# 51   You got a cousin who's tellin' you somethin'\n...
# 52   Hey there, weird kid in your high-top shoes\nS...
# 53   M-M-Mouse dropped a track\n\nI-N-D-E-P-E-N-D-E...
# 54   Girl you working with some ass, yeah... You ba...
# 58   Black Beatles in the city be back immediately\...
# 61   (Chorus 2X: samples from "Still Tippin'")\n"Ba...
# 62   Remy Boyz, yeah\n1738\n\nI'm like "hey, what's...
# 63   I said, "Grandpa, what's this picture here?\nI...
# 64   Nobody pray for me\nEven a day for me\nWay (ye...
# 76   I buried my heart in a hole in the ground\nWit...
# 77   Give me something I haven't seen\nGive me the ...
# ..                                                 ...
# 544  Believe me, Natalie\nListen, Natalie\nThis is ...
# 547  You fault my pride\nDon't ever need to apologi...
# 549  It's bugging me\nGrating me\nAnd twisting me a...
# 550  Just another lesson learned\nWear a scar, a bo...
# 551  Went too fast, ran out of luck\nAnd I don't ev...
# 557  I'm in you, you're in me\nI can't tell\nYou're...
# 559  Uh!\n\nThe movie ran through me\nThe glamor su...
# 562  I came into this world as a reject\nLook into ...
# 563  Whenever I'm alone with you\nYou make me feel ...
# 564  Ain't nobody dope as me, I'm dressed so fresh,...
# 565  Call it magic\nCall it true\nI call it magic\n...
# 567  Bless my heart\nBless my soul\nDidn't think I'...
# 568  Hello, I've waited here for you\nEverlong\nTon...
# 569  Every time I turn around\nA man tries to get m...
# 572  She's a yellow pair of running shoes, an' a ho...
# 576  Turn the quiet up, turn the noise down\nLet th...
# 578  At the count of three\nI want everybody in the...
# 579  All I need, all all I need\nAll I need, all al...
# 580  Well, daddy joined the Air Force\nSaid it was ...
# 581  I'm the fuckin' man, y'all don't get it, do ya...
# 583  It's 50\nIt's The Unit\nThat means it's money ...
# 586  Du du... du du... dun dun it all... dun dun it...
# 588  Im a New Orleans gangtsa, after the storm\nBoy...
# 589  Bite down, shawty chewin' like a billygoat\nGo...
# 591  Drizzy\n\nMake it so fresh, Y-M,\nSo fly so pr...
# 592  Dudes dat neva spoke \n2 me now wanna speak \n...
# 596  Waka waka flocka flame waka flocka flame waka ...
# 601  (Verse 1: Waka Flocka Flame)\nI said my neckla...
# 604  Ay suckas hate to see me get it like so, so\nB...
# 608  Spit yo game, talk yo shit, grab yo gat\nCall ...
#
#                                          lyricsCleaned  \
# 2    Sherry was a waitress at the only joint in tow...
# 8    It was a beautiful day the sun beat down I had...
# 9    Unfortunately we are not licensed to display t...
# 11   Do I find it so hard When I know in my heart I...
# 12   Cant explain all the feelings that youre makin...
# 13   Desperate for changing Starving for truth Im c...
# 19   You sit there in your heartache Waitin on some...
# 25   Donna Missal We got that bad love but it taste...
# 27   Would you fuck me for free Another one We the ...
# 28   You know alot of girls be Thinkin my songs are...
# 30   Started Zombie on the track  Started from the ...
# 31   Im the fuckin man yall dont get it do ya Type ...
# 32   Kyla Baby I like your style  Drake Grips on yo...
# 36   Look out cause you know what youre doing Turn ...
# 38   Turn on a neon light At least make it feel lik...
# 39   People are strange when youre a stranger Faces...
# 41   You know that it would be untrue You know that...
# 48   Know it sounds funny But I just cant stand the...
# 50   So here we are here all alone The band quit pl...
# 51   You got a cousin whos tellin you somethin That...
# 52   Hey there weird kid in your hightop shoes Sitt...
# 53   MMMouse dropped a track  INDEPENDENT do you kn...
# 54   Girl you working with some ass yeah You bad ye...
# 58   Black Beatles in the city be back immediately ...
# 61   Chorus 2X samples from Still Tippin Back then ...
# 62   Remy Boyz yeah 1738  Im like hey whats up hell...
# 63   I said Grandpa whats this picture here Its all...
# 64   Nobody pray for me Even a day for me Way yeah ...
# 76   I buried my heart in a hole in the ground With...
# 77   Give me something I havent seen Give me the re...
# ..                                                 ...
# 544  Believe me Natalie Listen Natalie This is your...
# 547  You fault my pride Dont ever need to apologize...
# 549  Its bugging me Grating me And twisting me arou...
# 550  Just another lesson learned Wear a scar a bore...
# 551  Went too fast ran out of luck And I dont even ...
# 557  Im in you youre in me I cant tell Youre so cru...
# 559  Uh  The movie ran through me The glamor subdue...
# 562  I came into this world as a reject Look into t...
# 563  Whenever Im alone with you You make me feel li...
# 564  Aint nobody dope as me Im dressed so fresh so ...
# 565  Call it magic Call it true I call it magic Whe...
# 567  Bless my heart Bless my soul Didnt think Id ma...
# 568  Hello Ive waited here for you Everlong Tonight...
# 569  Every time I turn around A man tries to get me...
# 572  Shes a yellow pair of running shoes an a holey...
# 576  Turn the quiet up turn the noise down Let this...
# 578  At the count of three I want everybody in the ...
# 579  All I need all all I need All I need all all I...
# 580  Well daddy joined the Air Force Said it was a ...
# 581  Im the fuckin man yall dont get it do ya Type ...
# 583  Its 50 Its The Unit That means its money Ha ha...
# 586  Du du du du dun dun it all dun dun it all Who ...
# 588  Im a New Orleans gangtsa after the storm Boy i...
# 589  Bite down shawty chewin like a billygoat Goin ...
# 591  Drizzy  Make it so fresh YM So fly so priceles...
# 592  Dudes dat neva spoke  2 me now wanna speak  Gi...
# 596  Waka waka flocka flame waka flocka flame waka ...
# 601  Verse 1 Waka Flocka Flame I said my necklace  ...
# 604  Ay suckas hate to see me get it like so so Bit...
# 608  Spit yo game talk yo shit grab yo gat Call yo ...
#
#                                                  title
# 2                             The Road Goes On Forever
# 8                                 Runnin' Down A Dream
# 9                                         Free Fallin'
# 11                                                4:44
# 12                    I Believe In A Thing Called Love
# 13                                 Hanging By a Moment
# 19                                 When You Were Young
# 25                        Over It (feat. Donna Missal)
# 27                              For Free (feat. Drake)
# 28                                     Best I Ever Had
# 30                             Started From The Bottom
# 31                         The Motto (feat. Lil Wayne)
# 32                     One Dance (feat. WizKid & Kyla)
# 36                                           La Dee Da
# 38   Mixed Drinks About Feelings (Live At Denny San...
# 39                                  People Are Strange
# 41                                       Light My Fire
# 48                          Easy (feat. Willie Nelson)
# 50                                Baby Be My Love Song
# 51                                   Lovin' You Is Fun
# 52                                   Mr. Misunderstood
# 53       Independent (feat. Lil' Boosie and Lil' Phat)
# 54                                    Back That Azz Up
# 58                    Black Beatles (feat. Gucci Mane)
# 61                                           Back Then
# 62                                          Trap Queen
# 63                                            In Color
# 64                                             HUMBLE.
# 76                                      What Went Down
# 77                                         Give It All
# ..                                                 ...
# 544                                 Believe Me Natalie
# 547                                              Crawl
# 549                                           Hysteria
# 550                                     Lesson Learned
# 551                                 Do It For The Kids
# 557                                    First It Giveth
# 559                                            Testify
# 562                                             Nookie
# 563                                          Love Song
# 564                                 So Fresh, So Clean
# 565                                              Magic
# 567                                            Hold On
# 568                        Everlong (Acoustic Version)
# 569                                     The Other Side
# 572                                   She's Everything
# 576                               Smoke a Little Smoke
# 578  Let Me Clear My Throat (Old School Reunion Rem...
# 579                                         All I Need
# 580                                          KMAG YOYO
# 581                        The Motto (feat. Lil Wayne)
# 583  I Don't Know, Officer (Explicit) (feat. Lloyd ...
# 586                                         Dunn, Dunn
# 588                                         What U Kno
# 589                                           I'm Dumb
# 591          Mo Milly (Explicit) (feat. Drake & Bun B)
# 592                                          By Myself
# 596  O Let's Do It (Feat. Cap) [Explicit Album Vers...
# 601  Bricksquad (feat. Gudda Gudda) [Explicit Album...
# 604                                            Like So
# 608                                            Spitter
#
# [242 rows x 5 columns]

# %% [markdown]
# ### So finally have all the data I want to use into the data frame. Time to get down to business... I'll start by splitting the data into training data and test data.

# %%
X_train, X_test = train_test_split(songDataFrame, test_size=.25,stratify=songDataFrame.genre)
y_train = X_train.genre
y_test = X_test.genre

# %% [markdown]
# ### I chose to use the TfidfVectorizer from the scikit-learn package to vectorize the songs. I used the TfidfVectorizer over the CountVectorizer to minimize the effect that the lyric-length could have on classification. This results in a sparse matrix in which the rows are the samples (songs) and the columns are the features (words or n-grams).

# %%
vectorizer = TfidfVectorizer(analyzer='word',max_df=.85, ngram_range=(1,1),stop_words='english')
vectorizer.fit(songDataFrame['lyricsCleaned'])
# Out:
# TfidfVectorizer(analyzer='word', binary=False, decode_error='strict',
#         dtype=<class 'numpy.int64'>, encoding='utf-8', input='content',
#         lowercase=True, max_df=0.85, max_features=None, min_df=1,
#         ngram_range=(1, 1), norm='l2', preprocessor=None, smooth_idf=True,
#         stop_words='english', strip_accents=None, sublinear_tf=False,
#         token_pattern='(?u)\\b\\w\\w+\\b', tokenizer=None, use_idf=True,
#         vocabulary=None)

# %% [markdown]
# ### I'm going to use a logistic regression model classifier because I want to keep it simple. Depending on how this works I may explore a Naive-Bayes classifier or an SVM based classifier. I'm using the 'lbfgs' solver because my data is small-ish. I'm also using a 'balanced' class weight to compensate for my unbalanced classes.

# %%
clf=LogisticRegression(solver='lbfgs',class_weight='balanced')
clf.fit(vectorizer.transform(X_train['lyricsCleaned']).toarray(),y_train)
# Out:
# LogisticRegression(C=1.0, class_weight='balanced', dual=False,
#           fit_intercept=True, intercept_scaling=1, max_iter=100,
#           multi_class='ovr', n_jobs=1, penalty='l2', random_state=None,
#           solver='lbfgs', tol=0.0001, verbose=0, warm_start=False)

# %%
predictions = clf.predict(vectorizer.transform(X_test['lyricsCleaned']).toarray())

# %% [markdown]
# ### Going to see how I did classifying the songs by genre. I'm going to use the F1 score because of my unbalanced classes.

# %%
F1 = f1_score(y_test,predictions,average='weighted')
round(F1,2)
# Out:
# 0.79000000000000004

# %% [markdown]
# ### An F1 score of .79 indicates that the classifier is performing reasonably well given that we are performing a multi-class classification using somewhat noisy data (I'm assuming that words common to all genres will make this noisy). Let's get a better look at what the classifier is picking up on... This function will display the top 15 features (words) associated with each genre.

# %%
def seeTopFeatures(vectorizer, clf, classLabels):
    featureNames = vectorizer.get_feature_names()
    for i, classLabel in enumerate(classLabels):
        topFeatures = np.argsort(clf.coef_[i])[-10:]
        print("%s: %s" % (classLabel, " ".join(featureNames[j] for j in topFeatures)))

# %%
seeTopFeatures(vectorizer,clf, ['Country', 'Rap', 'Rock'])
# Out:
# Country: days easy runs just drink creepin sudden wave shes little
# Rap: dun clean fuckin hol beast like money bitch niggas nigga
# Rock: feel youve come jealous stop sharona ooh away gimme oh

# %% [markdown]
# ### This is sort of what I expected to see. I can't make any definite conclusions from this analysis, but as a person that listens to country music, I can definitely understand how 'drink' and 'shes' made it into the top features. It seems as though the other top features for country are not country-specific
#
# ### Rap definitely takes the cake for having genre specific features. I suspect this is because these features comprise a large portion of the corpus of the rap data from my playlists.
#
# ### Rock is unique in that some of the features are more like 'fillers' than words. 'ooh' and 'oh' are examples of this. The other words associated with rock are general words, as was the case with country. I'm suspecting that most of the classification power is coming from the unique vocabulary associated with rap. Maybe some more digging can determine whether or not I'm right.

# %%
print(classification_report(y_test,predictions, labels=['Country', 'Rap', 'Rock'] ))
# Out:
#              precision    recall  f1-score   support
#
#     Country       0.88      0.54      0.67        13
#         Rap       0.88      0.64      0.74        11
#        Rock       0.78      0.95      0.85        37
#
# avg / total       0.82      0.80      0.79        61

# %% [markdown]
# ### Surprisingly, the classifier seems to perform best on rock music with acceptable precision and excellent recall. Rap music has a very high precision, meaning that it does not overpredict samples to be rap, when they are not; however, the recall is low, indicating a tendency to miss positive examples. Country music classification suffers from the same problem as rap -- high precision with low recall. An overall F1-score of .79 indicates a classifier that performs reasonably well given the nature of the data.
